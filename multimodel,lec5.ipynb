# %%
import os
os.environ['GEMINI_API_KEY'] = 'AIzaSyAHwDcOkORNwPLjwCpj-vcQlTRpP6PMViA'

# %%
# !pip install -q -U google-generativeai

# %%
import google.generativeai as genai
genai.configure(api_key=os.environ['GEMINI_API_KEY'])

# %%
model = genai.GenerativeModel('gemini-2.5-flash-preview-04-17')

# %%
response = model.generate_content('what is today date and time')
print(response.text)
# Out:
# As of my current access, the date and time are:
#
# **Sunday, May 26, 2024**
# **1:46 AM UTC**

# %%
response = model.generate_content('WHAT WOULD BE FUTURE SCOPE OF GENERATIVE AI IN 2030?')
print(response.text)
# Out:
# Okay, let's look at the likely scope of Generative AI (GenAI) by the year 2030. It's a relatively short timeframe, meaning many foundational elements are already in place, but it allows for significant maturation, integration, and widespread adoption.
#
# Here's a breakdown of the future scope:
#
# **1. Widespread Integration & "Ubiquitous Co-Pilots":**
#
# *   **Seamless Workflow Embedding:** GenAI won't just be standalone tools; it will be deeply embedded within nearly all software applications we use daily (word processors, spreadsheets, design tools, coding environments, CRM systems, etc.).
# *   **Personalized Assistants:** AI assistants will be far more sophisticated, multimodal (handling text, voice, image, video inputs/outputs seamlessly), and proactive, acting as highly personalized "co-pilots" for individuals and professionals across various tasks. They will understand context over long interactions.
#
# **2. Hyper-Personalized Content Creation & Consumption:**
#
# ...

# %%
import PIL.Image
img = PIL.Image.open('/ELEPHAT.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x148>

# %%
response = model.generate_content(img)
response
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "The image shows an adult elephant and a baby elephant (calf) standing together in a field of tall, golden-brown grass. They appear to be in a savanna or grassland environment."
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "index": 0
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 259,
#         "candidates_token_count": 37,
#         "total_token_count": 903
#       },
#       "model_version": "models/gemini-2.5-flash-preview-04-17"
#     }),
# )
